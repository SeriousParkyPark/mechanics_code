# %% [markdown]
# **420-SF2-RE: DS & OOP**
#
# **February 12, 2025**

# %% [markdown]
# # Assignment #1: drag with coffee filters
#
# For this assignment you will be allowed to use everything that has been covered in class regarding data science libraries.  **Any functions not covered in class will not be allowed to be used and will receive a grade of 0**.
#
# ${\color{red}\text{You should not be making any direct changes to your .csv files.}}\\$
# ${\color{red}\text{All changes done in this assignment must be done using Python code.}}$

# %% [markdown]
# ## Part 1: experiment with single coffee filter, 10 runs
# **Part 1 DUE DATE: end of class today**
#
# **Part 1 is worth 60% of Assignment #1**
#
# **Part 1 of the assignment is an in-class assignment.  Failure to be in class will receive a grade of 0 for Part 1 of the assignment and late submissions will not be accepted.**
#
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - Late submissions of Part 1 (that is, submissions outside of class) will receive a ${\color{red}\text{late penalty}}$. Part 1 may not be submitted later than **Wendesday, February 12 ay 23:59**.
#
# #### Instructions for Part 1:

# %% [markdown]
# 1. Import all necessary libraries, such as `pandas`, `matplotlib.pyplot`, `numpy`, etc.

# %%
# your code for step 1 goes here:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 2. Read  your `.csv` file that has the data of the single filter experiment into a DataFrame called `df`
# 3. Display the content of the data frame to the screen

# %%
# your code for steps 2 and 3 go here:
df = pd.read_csv("One_Filter_Experiment.csv")
df
# Out:
#      Time (s) Run #1  Position (m) Run #1  Velocity (m/s) Run #1  \
# 0               0.00                 0.97                    NaN
# 1               0.02                 0.97              -0.030000
# 2               0.04                 0.97              -0.010000
# 3               0.06                 0.97               0.000628
# 4               0.08                 0.97               0.010000
# ..               ...                  ...                    ...
# 110              NaN                  NaN                    NaN
# 111              NaN                  NaN                    NaN
# 112              NaN                  NaN                    NaN
# 113              NaN                  NaN                    NaN
# 114              NaN                  NaN                    NaN
#
#      Acceleration (m/s²) Run #1  Time (s) Run #2  Position (m) Run #2  \
# 0                           NaN             0.00                 0.98
# 1                           NaN             0.02                 0.98
# 2                          0.72             0.04                 0.98
# 3                          0.46             0.06                 0.98
# 4                          0.25             0.08                 0.98
# ..                          ...              ...                  ...
# 110                         NaN              NaN                  NaN
# 111                         NaN              NaN                  NaN
# 112                         NaN              NaN                  NaN
# 113                         NaN              NaN                  NaN
# 114                         NaN              NaN                  NaN
#
#      Velocity (m/s) Run #2  Acceleration (m/s²) Run #2  Time (s) Run #3  \
# 0                      NaN                         NaN             0.00
# 1                    -0.07                         NaN             0.02
# 2                     0.00                        2.27             0.04
# 3                     0.02                        0.77             0.06
# 4                     0.02                       -0.07             0.08
# ..                     ...                         ...              ...
# 110                    NaN                         NaN              NaN
# 111                    NaN                         NaN              NaN
# 112                    NaN                         NaN              NaN
# 113                    NaN                         NaN              NaN
# 114                    NaN                         NaN              NaN
#
#      Position (m) Run #3  ...  Velocity (m/s) Run #8  \
# 0                    0.9  ...                    NaN
# 1                    0.9  ...                  -0.14
# 2                    0.9  ...                  -0.17
# 3                    0.9  ...                  -0.20
# 4                    0.9  ...                  -0.24
# ..                   ...  ...                    ...
# 110                  NaN  ...                    NaN
# 111                  NaN  ...                    NaN
# 112                  NaN  ...                    NaN
# 113                  NaN  ...                    NaN
# 114                  NaN  ...                    NaN
#
#      Acceleration (m/s²) Run #8  Time (s) Run #9  Position (m) Run #9  \
# 0                           NaN             0.00                  0.8
# 1                           NaN             0.02                  0.8
# 2                         -1.63             0.04                  0.8
# 3                         -1.57             0.06                  0.8
# 4                         -1.43             0.08                  0.8
# ..                          ...              ...                  ...
# 110                         NaN              NaN                  NaN
# 111                         NaN              NaN                  NaN
# 112                         NaN              NaN                  NaN
# 113                         NaN              NaN                  NaN
# 114                         NaN              NaN                  NaN
#
#      Velocity (m/s) Run #9  Acceleration (m/s²) Run #9  Time (s) Run #10  \
# 0                      NaN                         NaN              0.00
# 1                     0.00                         NaN              0.02
# 2                     0.00                       -0.87              0.04
# 3                    -0.03                       -1.24              0.06
# 4                    -0.07                       -0.51              0.08
# ..                     ...                         ...               ...
# 110                    NaN                         NaN               NaN
# 111                    NaN                         NaN               NaN
# 112                    NaN                         NaN               NaN
# 113                    NaN                         NaN               NaN
# 114                    NaN                         NaN               NaN
#
#      Position (m) Run #10  Velocity (m/s) Run #10  Acceleration (m/s²) Run #10
# 0                    0.86                     NaN                          NaN
# 1                    0.86                -0.02000                          NaN
# 2                    0.86                 0.00000                         0.50
# 3                    0.86                 0.00000                         0.20
# 4                    0.86                 0.00018                        -0.02
# ..                    ...                     ...                          ...
# 110                   NaN                     NaN                          NaN
# 111                   NaN                     NaN                          NaN
# 112                   NaN                     NaN                          NaN
# 113                   NaN                     NaN                          NaN
# 114                   NaN                     NaN                          NaN
#
# [115 rows x 40 columns]

# %% [markdown]
# 4. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.  You **should not** manually adjust the content of the `data_df` for each run.
# 5. Display the content of `data_df`

# %%
# Your code for steps 4 and 5 go here:
columns_filter1 = list(df.columns[0:40:4])
columns_filter2 = list(df.columns[1:40:4])
filter = columns_filter1 + columns_filter2
data_df = df[filter]
data_df = data_df.dropna()
data_df
# Out:
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 72             1.44             1.44             1.44             1.44
# 73             1.46             1.46             1.46             1.46
# 74             1.48             1.48             1.48             1.48
# 75             1.50             1.50             1.50             1.50
# 76             1.52             1.52             1.52             1.52
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# ..              ...              ...              ...              ...
# 72             1.44             1.44             1.44             1.44
# 73             1.46             1.46             1.46             1.46
# 74             1.48             1.48             1.48             1.48
# 75             1.50             1.50             1.50             1.50
# 76             1.52             1.52             1.52             1.52
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 0.97
# 1              0.02              0.02                 0.97
# 2              0.04              0.04                 0.97
# 3              0.06              0.06                 0.97
# 4              0.08              0.08                 0.97
# ..              ...               ...                  ...
# 72             1.44              1.44                 0.29
# 73             1.46              1.46                 0.28
# 74             1.48              1.48                 0.26
# 75             1.50              1.50                 0.24
# 76             1.52              1.52                 0.23
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  0.98                 0.90                 0.90
# 1                  0.98                 0.90                 0.89
# 2                  0.98                 0.90                 0.89
# 3                  0.98                 0.90                 0.89
# 4                  0.98                 0.90                 0.89
# ..                  ...                  ...                  ...
# 72                 0.32                 0.27                 0.33
# 73                 0.30                 0.28                 0.32
# 74                 0.29                 0.26                 0.30
# 75                 0.27                 0.25                 0.29
# 76                 0.26                 0.24                 0.27
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  0.87                 1.00                 0.94
# 1                  0.87                 1.00                 0.93
# 2                  0.87                 1.00                 0.93
# 3                  0.87                 1.00                 0.92
# 4                  0.87                 1.00                 0.92
# ..                  ...                  ...                  ...
# 72                 0.20                 0.34                 0.12
# 73                 0.19                 0.33                 0.12
# 74                 0.17                 0.31                 0.12
# 75                 0.16                 0.30                 0.10
# 76                 0.14                 0.29                 1.86
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  0.92                 0.80                  0.86
# 1                  0.92                 0.80                  0.86
# 2                  0.92                 0.80                  0.86
# 3                  0.91                 0.80                  0.86
# 4                  0.91                 0.80                  0.86
# ..                  ...                  ...                   ...
# 72                 0.12                 0.12                  0.25
# 73                 0.12                 0.12                  0.22
# 74                 0.14                 0.10                  0.20
# 75                 0.13                 1.84                  0.19
# 76                 0.13                 1.84                  0.17
#
# [77 rows x 20 columns]

# %% [markdown]
# 6. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include the curved data that transitions into a drop in position.  You should only keep about 0.5 to 1 second of the roughly constant position values before the drop of position takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
#
# 7. Store your clean data into a new DataFrame called `clean_df`.
# 8. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 9. Write this to a new .csv file called `"clean_data_single_filter.csv"`.

# %%
# Your code for steps 6-9 go here:
def cleanDf(dataF, column1):
    absmin = dataF[column1].min()
    absmax = dataF[column1][:50].max()
    absminindex = dataF.index[dataF[column1] == absmin][0]
    absmaxindex = dataF.index[dataF[column1] == absmax][-1]
    if absmax - dataF[column1][absmaxindex+4:50].max() < 0.03:
        absmaxindex = dataF.index[dataF[column1] == dataF[column1][absmaxindex+4:50].max()][-1]
    new_df = dataF[:absminindex+1]
    increasingcheck = False
    pre = absminindex-1
    temp = int(absminindex) #so that a pointer is not created just in case In want to use absminindex later
    for _ in range(10):
        if new_df[column1][pre] <= new_df[column1][temp]: 
            increasingcheck = True
        else:
            temp -= 1
            pre -= 1
    if increasingcheck:
        while new_df[column1][pre] <= new_df[column1][temp]:
            temp -= 1
            pre -= 1
        absminindex = pre
    new_df = dataF[absmaxindex:absminindex+1]
    return new_df


clean_df = data_df
for i in range(1, 11):
    temp_df = data_df[[f"Position (m) Run #{i}",f"Time (s) Run #{i}"]]
    new_df = cleanDf(temp_df, f"Position (m) Run #{i}")
    new_df = new_df.dropna().reset_index(drop=True)
    clean_df[f"Position (m) Run #{i}"] = new_df[f"Position (m) Run #{i}"]
    clean_df[f"Time (s) Run #{i}"] = new_df[f"Time (s) Run #{i}"]
    for x in range(len(clean_df[f"Time (s) Run #{i}"])):
        clean_df.loc[x, f"Time (s) Run #{i}"] = 0.02*x

    


clean_df.to_csv("clean_data_single_filter.csv", encoding='utf-8', index=False)

# %% [markdown]
# 10. Plot the data using `matplotlib` from all 10 runs as scatter plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.
# - scale the size of the points so that they are not too big.
# Note that you should automate the process of plotting the 10 graphs.
#
# 11. Take the last 0.5 to 1 second of the x-values in your 10 runs, and draw a line of best fit on all your 10 graphs.

# %%
plt.figure(figsize=(15, 10))
coeff_lst = []

for i in range(1, 11):
    xpoints = clean_df[f"Time (s) Run #{i}"]
    ypoints = clean_df[f"Position (m) Run #{i}"]
    plt.scatter(xpoints, ypoints, label=f"Run #{i}")
    lastindex = (ypoints == ypoints.min())
    lastindex
    absmin = ypoints.min()
    absminindex = clean_df.index[clean_df[f"Position (m) Run #{i}"] == absmin][0]
    regxpoints = clean_df[f"Time (s) Run #{i}"][absminindex-20:absminindex]
    regypoints = clean_df[f"Position (m) Run #{i}"][absminindex-20:absminindex]
    coeff = np.polyfit(regxpoints, regypoints, deg = 1)
    coeff_lst.append(coeff[0])
    best_fit_function = np.poly1d(coeff)
    plt.plot(regxpoints, best_fit_function(regxpoints), label = 'Regression Fit #{i}')

    
plt.xlabel("Time (s)")
plt.ylabel("Position (m)")
plt.title("Position vs Time of 10 Runs of Single Filter Drop")
plt.legend(title="Runs")
plt.show()
list(map(float,coeff_lst))
# Out:
# [-0.7552631578947369,
#  -0.6763157894736844,
#  -0.6402255639097749,
#  -0.7315789473684213,
#  -0.7131578947368422,
#  -0.6887218045112791,
#  -0.7244360902255631,
#  -0.7661654135338344,
#  -0.7240601503759397,
#  -0.6492481203007521]

# %% [markdown]
# ### ${\color{green} \text{Submit your work to moodle and git for Part 1 before moving to Part 2}}$

# %% [markdown]
# ## Part 2: experiment with multiple coffee filters, 10 runs
# **Part 2 DUE DATE: Friday, February 14 at 20:00**
#
# **Part 2 is worth 40% of Assignment #1**
#
# #### Submission:
# - Upload all new and updated files to moodle under ${\color{green}\text{Assignment \#1}}$.  Make sure to not delete or overwrite any files during your previous submissions.
# - `add`, `commit`, `push` all new and updated files to ${\color{green}\text{git}}$ in your **Assignment #1** folder
# - late submissions of Part 2 will receive a grade of 0.
#
#
# #### Instructions for Part 2:

# %% [markdown]
# 1. Read  your .csv file that has the data of filters of varying mass into a DataFrame `df`.
# 3. Display the content of the DataFrame to the screen

# %%
# Your code for steps 1 and 2 go here:
df = pd.read_csv("Multiple_Filter_Experiment.csv")
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', None)
df['Position (m) Run #8']
# Out:
# 0     1.01
# 1     1.00
# 2     1.00
# 3     1.00
# 4     1.01
# 5     1.00
# 6     0.99
# 7     0.99
# 8     0.98
# 9     0.96
# 10    0.95
# 11    0.94
# 12    0.92
# 13    0.91
# 14    0.89
# 15    0.87
# 16    0.86
# 17    0.84
# 18    0.82
# 19    0.80
# 20    0.77
# 21    0.75
# 22    0.72
# 23    0.70
# 24    0.67
# 25    0.65
# 26    0.62
# 27    0.59
# 28    0.56
# 29    0.54
# 30    0.51
# 31    0.48
# 32    0.45
# 33    0.42
# 34    0.39
# 35    0.35
# 36    0.32
# 37    0.29
# 38    0.26
# 39    0.23
# 40    0.20
# 41    0.17
# 42    0.13
# 43    0.12
# 44    0.12
# 45    0.09
# 46    3.35
# 47    1.06
# 48    1.02
# 49    1.03
# 50    1.04
# 51    1.04
# 52    1.03
# 53     NaN
# 54     NaN
# 55     NaN
# 56     NaN
# 57     NaN
# 58     NaN
# 59     NaN
# 60     NaN
# 61     NaN
# 62     NaN
# 63     NaN
# 64     NaN
# 65     NaN
# 66     NaN
# 67     NaN
# 68     NaN
# 69     NaN
# 70     NaN
# 71     NaN
# 72     NaN
# 73     NaN
# Name: Position (m) Run #8, dtype: float64

# %% [markdown]
# 3. Extract from the DataFrame `df` into a new DataFrame `data_df` only the **Time** and **Position** columns for the 10 runs.  Here are the details of how your `data_df` should look:
# - Time column titles should read: **Time (s) Run #$i$** for $0\leq i\leq 10$
# - Position column titles should read: **Position (m) Run #$i$** for $0\leq i\leq 10$
# - The order of the columns in your `data_df` should first display all the **Time** columns then all the **Position** columns.
# - all NaN values should be dropped from `data_df`
# Note that this process should be automated.
# 4. Display the content of `data_df`

# %%
# Your code for steps 3 and 4 go here:
df_filter1 = list(df.columns[0:40:4])
df_filter2 = list(df.columns[1:40:4])
filter = df_filter1 + df_filter2
data_df = df[filter]
data_df = data_df.dropna()
data_df[]
# Out:
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# 5              0.10             0.10             0.10             0.10
# 6              0.12             0.12             0.12             0.12
# 7              0.14             0.14             0.14             0.14
# 8              0.16             0.16             0.16             0.16
# 9              0.18             0.18             0.18             0.18
# 10             0.20             0.20             0.20             0.20
# 11             0.22             0.22             0.22             0.22
# 12             0.24             0.24             0.24             0.24
# 13             0.26             0.26             0.26             0.26
# 14             0.28             0.28             0.28             0.28
# 15             0.30             0.30             0.30             0.30
# 16             0.32             0.32             0.32             0.32
# 17             0.34             0.34             0.34             0.34
# 18             0.36             0.36             0.36             0.36
# 19             0.38             0.38             0.38             0.38
# 20             0.40             0.40             0.40             0.40
# 21             0.42             0.42             0.42             0.42
# 22             0.44             0.44             0.44             0.44
# 23             0.46             0.46             0.46             0.46
# 24             0.48             0.48             0.48             0.48
# 25             0.50             0.50             0.50             0.50
# 26             0.52             0.52             0.52             0.52
# 27             0.54             0.54             0.54             0.54
# 28             0.56             0.56             0.56             0.56
# 29             0.58             0.58             0.58             0.58
# 30             0.60             0.60             0.60             0.60
# 31             0.62             0.62             0.62             0.62
# 32             0.64             0.64             0.64             0.64
# 33             0.66             0.66             0.66             0.66
# 34             0.68             0.68             0.68             0.68
# 35             0.70             0.70             0.70             0.70
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# 5              0.10             0.10             0.10             0.10
# 6              0.12             0.12             0.12             0.12
# 7              0.14             0.14             0.14             0.14
# 8              0.16             0.16             0.16             0.16
# 9              0.18             0.18             0.18             0.18
# 10             0.20             0.20             0.20             0.20
# 11             0.22             0.22             0.22             0.22
# 12             0.24             0.24             0.24             0.24
# 13             0.26             0.26             0.26             0.26
# 14             0.28             0.28             0.28             0.28
# 15             0.30             0.30             0.30             0.30
# 16             0.32             0.32             0.32             0.32
# 17             0.34             0.34             0.34             0.34
# 18             0.36             0.36             0.36             0.36
# 19             0.38             0.38             0.38             0.38
# 20             0.40             0.40             0.40             0.40
# 21             0.42             0.42             0.42             0.42
# 22             0.44             0.44             0.44             0.44
# 23             0.46             0.46             0.46             0.46
# 24             0.48             0.48             0.48             0.48
# 25             0.50             0.50             0.50             0.50
# 26             0.52             0.52             0.52             0.52
# 27             0.54             0.54             0.54             0.54
# 28             0.56             0.56             0.56             0.56
# 29             0.58             0.58             0.58             0.58
# 30             0.60             0.60             0.60             0.60
# 31             0.62             0.62             0.62             0.62
# 32             0.64             0.64             0.64             0.64
# 33             0.66             0.66             0.66             0.66
# 34             0.68             0.68             0.68             0.68
# 35             0.70             0.70             0.70             0.70
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 1.11
# 1              0.02              0.02                 1.11
# 2              0.04              0.04                 1.11
# 3              0.06              0.06                 1.11
# 4              0.08              0.08                 1.11
# 5              0.10              0.10                 1.11
# 6              0.12              0.12                 1.11
# 7              0.14              0.14                 1.11
# 8              0.16              0.16                 1.11
# 9              0.18              0.18                 1.11
# 10             0.20              0.20                 1.10
# 11             0.22              0.22                 1.10
# 12             0.24              0.24                 1.10
# 13             0.26              0.26                 1.10
# 14             0.28              0.28                 1.10
# 15             0.30              0.30                 1.09
# 16             0.32              0.32                 1.08
# 17             0.34              0.34                 1.06
# 18             0.36              0.36                 1.04
# 19             0.38              0.38                 1.02
# 20             0.40              0.40                 1.00
# 21             0.42              0.42                 0.98
# 22             0.44              0.44                 0.95
# 23             0.46              0.46                 0.92
# 24             0.48              0.48                 0.89
# 25             0.50              0.50                 0.85
# 26             0.52              0.52                 0.82
# 27             0.54              0.54                 0.78
# 28             0.56              0.56                 0.74
# 29             0.58              0.58                 0.70
# 30             0.60              0.60                 0.65
# 31             0.62              0.62                 0.61
# 32             0.64              0.64                 0.56
# 33             0.66              0.66                 0.51
# 34             0.68              0.68                 0.46
# 35             0.70              0.70                 0.41
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  1.06                 1.05                 1.03
# 1                  1.05                 1.05                 1.03
# 2                  1.05                 1.05                 1.03
# 3                  1.05                 1.05                 1.03
# 4                  1.05                 1.05                 1.03
# 5                  1.05                 1.05                 1.02
# 6                  1.05                 1.05                 1.02
# 7                  1.05                 1.05                 1.02
# 8                  1.05                 1.05                 1.01
# 9                  1.05                 1.05                 1.01
# 10                 1.05                 1.05                 1.00
# 11                 1.04                 1.04                 0.99
# 12                 1.03                 1.04                 0.97
# 13                 1.02                 1.03                 0.95
# 14                 1.00                 1.02                 0.93
# 15                 0.99                 1.01                 0.91
# 16                 0.97                 0.99                 0.88
# 17                 0.95                 0.97                 0.86
# 18                 0.92                 0.95                 0.83
# 19                 0.89                 0.93                 0.80
# 20                 0.86                 0.90                 0.77
# 21                 0.83                 0.87                 0.74
# 22                 0.80                 0.85                 0.70
# 23                 0.77                 0.81                 0.68
# 24                 0.73                 0.78                 0.63
# 25                 0.69                 0.75                 0.59
# 26                 0.65                 0.71                 0.55
# 27                 0.61                 0.67                 0.50
# 28                 0.57                 0.63                 0.46
# 29                 0.52                 0.59                 0.42
# 30                 0.48                 0.55                 0.37
# 31                 0.43                 0.50                 0.32
# 32                 0.38                 0.45                 0.27
# 33                 0.33                 0.41                 0.23
# 34                 0.28                 0.36                 0.18
# 35                 0.23                 0.31                 0.13
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  1.13                 1.07                 1.02
# 1                  1.12                 1.07                 1.02
# 2                  1.12                 1.07                 1.02
# 3                  1.12                 1.07                 1.02
# 4                  1.12                 1.07                 1.02
# 5                  1.12                 1.07                 1.02
# 6                  1.12                 1.07                 1.02
# 7                  1.12                 1.07                 1.02
# 8                  1.11                 1.06                 1.02
# 9                  1.11                 1.05                 1.01
# 10                 1.10                 1.04                 1.01
# 11                 1.09                 1.03                 1.01
# 12                 1.07                 1.01                 1.00
# 13                 1.05                 0.99                 0.99
# 14                 1.04                 0.98                 0.98
# 15                 1.02                 0.96                 0.97
# 16                 0.99                 0.93                 0.95
# 17                 0.97                 0.91                 0.93
# 18                 0.94                 0.89                 0.91
# 19                 0.92                 0.86                 0.90
# 20                 0.89                 0.83                 0.87
# 21                 0.86                 0.80                 0.85
# 22                 0.83                 0.77                 0.83
# 23                 0.79                 0.74                 0.81
# 24                 0.76                 0.70                 0.78
# 25                 0.72                 0.67                 0.75
# 26                 0.69                 0.63                 0.73
# 27                 0.65                 0.59                 0.70
# 28                 0.61                 0.56                 0.67
# 29                 0.57                 0.52                 0.64
# 30                 0.53                 0.48                 0.61
# 31                 0.48                 0.44                 0.57
# 32                 0.44                 0.39                 0.54
# 33                 0.40                 0.35                 0.51
# 34                 0.35                 0.31                 0.47
# 35                 0.31                 0.26                 0.44
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  1.01                 1.02                  0.94
# 1                  1.00                 1.02                  0.94
# 2                  1.00                 1.02                  0.93
# 3                  1.00                 1.02                  0.93
# 4                  1.01                 1.02                  0.93
# 5                  1.00                 1.02                  0.93
# 6                  0.99                 1.01                  0.93
# 7                  0.99                 1.01                  0.93
# 8                  0.98                 1.00                  0.93
# 9                  0.96                 1.00                  0.93
# 10                 0.95                 0.99                  0.93
# 11                 0.94                 0.98                  0.93
# 12                 0.92                 0.97                  0.92
# 13                 0.91                 0.96                  0.92
# 14                 0.89                 0.94                  0.91
# 15                 0.87                 0.93                  0.91
# 16                 0.86                 0.92                  0.90
# 17                 0.84                 0.91                  0.89
# 18                 0.82                 0.89                  0.89
# 19                 0.80                 0.87                  0.87
# 20                 0.77                 0.86                  0.86
# 21                 0.75                 0.83                  0.85
# 22                 0.72                 0.82                  0.84
# 23                 0.70                 0.80                  0.83
# 24                 0.67                 0.78                  0.82
# 25                 0.65                 0.76                  0.81
# 26                 0.62                 0.74                  0.80
# 27                 0.59                 0.72                  0.79
# 28                 0.56                 0.70                  0.78
# 29                 0.54                 0.68                  0.77
# 30                 0.51                 0.66                  0.76
# 31                 0.48                 0.64                  0.75
# 32                 0.45                 0.62                  0.73
# 33                 0.42                 0.60                  0.72
# 34                 0.39                 0.58                  0.70
# 35                 0.35                 0.55                  0.69

# %% [markdown]
# 5. The data in `data_df` contains noisy data.  In this step you are to clean the noisy data (or extract the clean data). Your cleaned data **for each run**
# - must not include the data that is after once the filter hits the motion sensor
# - must include only the bit where a drop in position starts.  You should not include any constant position values before the drop of positions takes place.
# Note that you should clean your data for each of the 10 runs and you should automate this process in your code with logical conditions, loops, etc.
# 6. Store your clean data into a new DataFrame called `clean_df`.
# 7. Note that now that the values in the **Time** columns may have shifted due to the clean-up.  Update your `clean_df` to rescale all the **Time** columns to start the time from 0.0 in increments of 0.02.
# 8. Write this to a new .csv file called `"clean_data_multiple_filter.csv"`.

# %%
# Your code for steps 5-8 go here:
# Your code for steps 6-9 go here:
def cleanDf(dataF, column1):
    absmin = dataF[column1].min()
    absmax = dataF[column1][:50].max()
    absminindex = dataF.index[dataF[column1] == absmin][0]
    absmaxindex = dataF.index[dataF[column1] == absmax][-1]
    # if (absmax - dataF[column1][absmaxindex+4:50].max()) < 0.06:
    #     absmaxindex = dataF.index[dataF[column1] == dataF[column1][absmaxindex+4:50].max()][-1]
    new_df = dataF[:absminindex+1]
    increasingcheck = False
    pre = absminindex-1
    temp = int(absminindex) #so that a pointer is not created just in case In want to use absminindex later
    for _ in range(8):
        if new_df[column1][pre] <= new_df[column1][temp]: 
            increasingcheck = True
        else:
            temp -= 1
            pre -= 1
    if increasingcheck:
        while new_df[column1][pre] <= new_df[column1][temp]:
            temp -= 1
            pre -= 1
        absminindex = pre
    new_df = dataF[absmaxindex:absminindex+1]
    print(absmaxindex)
    return new_df


clean_df = data_df
for i in range(1, 11):
    temp_df = data_df[[f"Position (m) Run #{i}",f"Time (s) Run #{i}"]]
    new_df = cleanDf(temp_df, f"Position (m) Run #{i}")
    new_df = new_df.dropna().reset_index(drop=True)
    clean_df[f"Position (m) Run #{i}"] = new_df[f"Position (m) Run #{i}"]
    clean_df[f"Time (s) Run #{i}"] = new_df[f"Time (s) Run #{i}"]
    for x in range(len(clean_df[f"Time (s) Run #{i}"])):
        clean_df.loc[x, f"Time (s) Run #{i}"] = 0.02*x
    
clean_df.to_csv("clean_data_multiple_filter.csv", encoding='utf-8', index=False)
clean_df
# Out:
# 9
# 0
# 10
# 4
# 0
# 7
# 8
# 4
# 5
# 1
#     Time (s) Run #1  Time (s) Run #2  Time (s) Run #3  Time (s) Run #4  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# 5              0.10             0.10             0.10             0.10
# 6              0.12             0.12             0.12             0.12
# 7              0.14             0.14             0.14             0.14
# 8              0.16             0.16             0.16             0.16
# 9              0.18             0.18             0.18             0.18
# 10             0.20             0.20             0.20             0.20
# 11             0.22             0.22             0.22             0.22
# 12             0.24             0.24             0.24             0.24
# 13             0.26             0.26             0.26             0.26
# 14             0.28             0.28             0.28             0.28
# 15             0.30             0.30             0.30             0.30
# 16             0.32             0.32             0.32             0.32
# 17             0.34             0.34             0.34             0.34
# 18             0.36             0.36             0.36             0.36
# 19             0.38             0.38             0.38             0.38
# 20             0.40             0.40             0.40             0.40
# 21             0.42             0.42             0.42             0.42
# 22             0.44             0.44             0.44             0.44
# 23             0.46             0.46             0.46             0.46
# 24             0.48             0.48             0.48             0.48
# 25             0.50             0.50             0.50             0.50
# 26             0.52             0.52             0.52             0.52
# 27             0.54             0.54             0.54             0.54
# 28             0.56             0.56             0.56             0.56
# 29             0.58             0.58             0.58             0.58
# 30             0.60             0.60             0.60             0.60
# 31             0.62             0.62             0.62             0.62
# 32             0.64             0.64             0.64             0.64
# 33             0.66             0.66             0.66             0.66
# 34             0.68             0.68             0.68             0.68
# 35             0.70             0.70             0.70             0.70
#
#     Time (s) Run #5  Time (s) Run #6  Time (s) Run #7  Time (s) Run #8  \
# 0              0.00             0.00             0.00             0.00
# 1              0.02             0.02             0.02             0.02
# 2              0.04             0.04             0.04             0.04
# 3              0.06             0.06             0.06             0.06
# 4              0.08             0.08             0.08             0.08
# 5              0.10             0.10             0.10             0.10
# 6              0.12             0.12             0.12             0.12
# 7              0.14             0.14             0.14             0.14
# 8              0.16             0.16             0.16             0.16
# 9              0.18             0.18             0.18             0.18
# 10             0.20             0.20             0.20             0.20
# 11             0.22             0.22             0.22             0.22
# 12             0.24             0.24             0.24             0.24
# 13             0.26             0.26             0.26             0.26
# 14             0.28             0.28             0.28             0.28
# 15             0.30             0.30             0.30             0.30
# 16             0.32             0.32             0.32             0.32
# 17             0.34             0.34             0.34             0.34
# 18             0.36             0.36             0.36             0.36
# 19             0.38             0.38             0.38             0.38
# 20             0.40             0.40             0.40             0.40
# 21             0.42             0.42             0.42             0.42
# 22             0.44             0.44             0.44             0.44
# 23             0.46             0.46             0.46             0.46
# 24             0.48             0.48             0.48             0.48
# 25             0.50             0.50             0.50             0.50
# 26             0.52             0.52             0.52             0.52
# 27             0.54             0.54             0.54             0.54
# 28             0.56             0.56             0.56             0.56
# 29             0.58             0.58             0.58             0.58
# 30             0.60             0.60             0.60             0.60
# 31             0.62             0.62             0.62             0.62
# 32             0.64             0.64             0.64             0.64
# 33             0.66             0.66             0.66             0.66
# 34             0.68             0.68             0.68             0.68
# 35             0.70             0.70             0.70             0.70
#
#     Time (s) Run #9  Time (s) Run #10  Position (m) Run #1  \
# 0              0.00              0.00                 1.11
# 1              0.02              0.02                 1.10
# 2              0.04              0.04                 1.10
# 3              0.06              0.06                 1.10
# 4              0.08              0.08                 1.10
# 5              0.10              0.10                 1.10
# 6              0.12              0.12                 1.09
# 7              0.14              0.14                 1.08
# 8              0.16              0.16                 1.06
# 9              0.18              0.18                 1.04
# 10             0.20              0.20                 1.02
# 11             0.22              0.22                 1.00
# 12             0.24              0.24                 0.98
# 13             0.26              0.26                 0.95
# 14             0.28              0.28                 0.92
# 15             0.30              0.30                 0.89
# 16             0.32              0.32                 0.85
# 17             0.34              0.34                 0.82
# 18             0.36              0.36                 0.78
# 19             0.38              0.38                 0.74
# 20             0.40              0.40                 0.70
# 21             0.42              0.42                 0.65
# 22             0.44              0.44                 0.61
# 23             0.46              0.46                 0.56
# 24             0.48              0.48                 0.51
# 25             0.50              0.50                 0.46
# 26             0.52              0.52                 0.41
# 27             0.54              0.54                  NaN
# 28             0.56              0.56                  NaN
# 29             0.58              0.58                  NaN
# 30             0.60              0.60                  NaN
# 31             0.62              0.62                  NaN
# 32             0.64              0.64                  NaN
# 33             0.66              0.66                  NaN
# 34             0.68              0.68                  NaN
# 35             0.70              0.70                  NaN
#
#     Position (m) Run #2  Position (m) Run #3  Position (m) Run #4  \
# 0                  1.06                 1.05                 1.03
# 1                  1.05                 1.04                 1.02
# 2                  1.05                 1.04                 1.02
# 3                  1.05                 1.03                 1.02
# 4                  1.05                 1.02                 1.01
# 5                  1.05                 1.01                 1.01
# 6                  1.05                 0.99                 1.00
# 7                  1.05                 0.97                 0.99
# 8                  1.05                 0.95                 0.97
# 9                  1.05                 0.93                 0.95
# 10                 1.05                 0.90                 0.93
# 11                 1.04                 0.87                 0.91
# 12                 1.03                 0.85                 0.88
# 13                 1.02                 0.81                 0.86
# 14                 1.00                 0.78                 0.83
# 15                 0.99                 0.75                 0.80
# 16                 0.97                 0.71                 0.77
# 17                 0.95                 0.67                 0.74
# 18                 0.92                 0.63                 0.70
# 19                 0.89                 0.59                 0.68
# 20                 0.86                 0.55                 0.63
# 21                 0.83                 0.50                 0.59
# 22                 0.80                 0.45                 0.55
# 23                 0.77                 0.41                 0.50
# 24                 0.73                 0.36                 0.46
# 25                 0.69                 0.31                 0.42
# 26                 0.65                  NaN                 0.37
# 27                 0.61                  NaN                 0.32
# 28                 0.57                  NaN                 0.27
# 29                 0.52                  NaN                 0.23
# 30                 0.48                  NaN                 0.18
# 31                 0.43                  NaN                 0.13
# 32                 0.38                  NaN                  NaN
# 33                 0.33                  NaN                  NaN
# 34                 0.28                  NaN                  NaN
# 35                 0.23                  NaN                  NaN
#
#     Position (m) Run #5  Position (m) Run #6  Position (m) Run #7  \
# 0                  1.13                 1.07                 1.02
# 1                  1.12                 1.06                 1.01
# 2                  1.12                 1.05                 1.01
# 3                  1.12                 1.04                 1.01
# 4                  1.12                 1.03                 1.00
# 5                  1.12                 1.01                 0.99
# 6                  1.12                 0.99                 0.98
# 7                  1.12                 0.98                 0.97
# 8                  1.11                 0.96                 0.95
# 9                  1.11                 0.93                 0.93
# 10                 1.10                 0.91                 0.91
# 11                 1.09                 0.89                 0.90
# 12                 1.07                 0.86                 0.87
# 13                 1.05                 0.83                 0.85
# 14                 1.04                 0.80                 0.83
# 15                 1.02                 0.77                 0.81
# 16                 0.99                 0.74                 0.78
# 17                 0.97                 0.70                 0.75
# 18                 0.94                 0.67                 0.73
# 19                 0.92                 0.63                 0.70
# 20                 0.89                 0.59                 0.67
# 21                 0.86                 0.56                 0.64
# 22                 0.83                 0.52                 0.61
# 23                 0.79                 0.48                 0.57
# 24                 0.76                 0.44                 0.54
# 25                 0.72                 0.39                 0.51
# 26                 0.69                 0.35                 0.47
# 27                 0.65                 0.31                 0.44
# 28                 0.61                 0.26                  NaN
# 29                 0.57                  NaN                  NaN
# 30                 0.53                  NaN                  NaN
# 31                 0.48                  NaN                  NaN
# 32                 0.44                  NaN                  NaN
# 33                 0.40                  NaN                  NaN
# 34                 0.35                  NaN                  NaN
# 35                 0.31                  NaN                  NaN
#
#     Position (m) Run #8  Position (m) Run #9  Position (m) Run #10
# 0                  1.01                 1.02                  0.94
# 1                  1.00                 1.01                  0.93
# 2                  0.99                 1.01                  0.93
# 3                  0.99                 1.00                  0.93
# 4                  0.98                 1.00                  0.93
# 5                  0.96                 0.99                  0.93
# 6                  0.95                 0.98                  0.93
# 7                  0.94                 0.97                  0.93
# 8                  0.92                 0.96                  0.93
# 9                  0.91                 0.94                  0.93
# 10                 0.89                 0.93                  0.93
# 11                 0.87                 0.92                  0.92
# 12                 0.86                 0.91                  0.92
# 13                 0.84                 0.89                  0.91
# 14                 0.82                 0.87                  0.91
# 15                 0.80                 0.86                  0.90
# 16                 0.77                 0.83                  0.89
# 17                 0.75                 0.82                  0.89
# 18                 0.72                 0.80                  0.87
# 19                 0.70                 0.78                  0.86
# 20                 0.67                 0.76                  0.85
# 21                 0.65                 0.74                  0.84
# 22                 0.62                 0.72                  0.83
# 23                 0.59                 0.70                  0.82
# 24                 0.56                 0.68                  0.81
# 25                 0.54                 0.66                  0.80
# 26                 0.51                 0.64                  0.79
# 27                 0.48                 0.62                  0.78
# 28                 0.45                 0.60                  0.77
# 29                 0.42                 0.58                  0.76
# 30                 0.39                 0.55                  0.75
# 31                 0.35                  NaN                  0.73
# 32                  NaN                  NaN                  0.72
# 33                  NaN                  NaN                  0.70
# 34                  NaN                  NaN                  0.69
# 35                  NaN                  NaN                   NaN

# %% [markdown]
# 9. Plot the data from all 10 runs as line plots on the same figure using your cleaned data.
# - Each plot should have a label **Run #$i$** for $1\leq i\leq10$
# - The label on the x-axis should read **Time (s)**
# - The label on the y-axis should read **Position (m)**
# - Each plot should be in a different color and there should be a legend showing which colour is which run.

# %%
# Your code for step 9 goes here:
plt.figure(figsize=(15, 10))


for i in range(1, 11):
    xpoints = clean_df[f"Time (s) Run #{i}"]
    ypoints = clean_df[f"Position (m) Run #{i}"]
    plt.plot(xpoints, ypoints, label=f"Run #{i}")
    
plt.xlabel("Time (s)")
plt.ylabel("Position (m)")
plt.title("Position vs Time of 10 Runs of Single Filter Drop")
plt.legend(title="Runs")
plt.show()
